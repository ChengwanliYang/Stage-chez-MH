# %%
# -------------------------------------------------------------------------------- NOTEBOOK-CELL: CODE
# -*- coding: utf-8 -*-
import dataiku
import pandas as pd, numpy as np
from dataiku import pandasutils as pdu

# Read recipe inputs
transcriptions_0 = dataiku.Dataset("transcriptions_0")
transcriptions_0_df = transcriptions_0.get_dataframe()

bad_histoire_df = transcriptions_0_df # For this sample code, simply copy input to output

# -------------------------------------------------------------------------------- NOTEBOOK-CELL: CODE
texte_all = bad_histoire_df['text_diarise']
liste_texte_all = list(texte_all)
id_conv_all = bad_histoire_df['nom']
domaine_all = bad_histoire_df['domaine_acte']
famille_all = bad_histoire_df['famille_acte']
objet_all =famille = bad_histoire_df['objet_acte']

# -------------------------------------------------------------------------------- NOTEBOOK-CELL: CODE
liste_texte_10 = []
liste_id_conv = []
liste_domaine = []
liste_famille = []
liste_objet = []

liste_bad = ["mauvais","mauvaise","j'attends"]
for j in liste_bad:

    for i in range(len(liste_texte_all)):

        if j in liste_texte_all[i]:

            liste_texte_10.append(liste_texte_all[i])

            id_conv = id_conv_all[i]
            liste_id_conv.append(id_conv)

            domaine = domaine_all[i]
            liste_domaine.append(domaine)

            famille = famille_all[i]
            liste_famille.append(famille)

            objet = objet_all[i]
            liste_objet.append(objet)

#print(liste_texte_10)

# -------------------------------------------------------------------------------- NOTEBOOK-CELL: CODE
new_df = pd.DataFrame(columns = ['transcription_id','text_all','domaine_acte','famille_acte','objet_acte'])
new_df['transcription_id'] = liste_id_conv
new_df['text_all'] = liste_texte_10
new_df['domaine_acte'] = liste_domaine
new_df['famille_acte'] = liste_famille
new_df['objet_acte'] = liste_objet

# -------------------------------------------------------------------------------- NOTEBOOK-CELL: CODE
trans_bad = dataiku.Dataset("bad_histoire")
trans_bad.write_with_schema(new_df)
