# %%
# -------------------------------------------------------------------------------- NOTEBOOK-CELL: CODE
# -*- coding: utf-8 -*-
import dataiku
import pandas as pd, numpy as np
from dataiku import pandasutils as pdu

# Read recipe inputs
joa_speech_adh_with_recla = dataiku.Dataset("joa_speech_adh_with_recla")
joa_speech_adh_with_recla_df = joa_speech_adh_with_recla.get_dataframe()
liste_texte = list(joa_speech_adh_with_recla_df['text_diarise'])
liste_nom = list(joa_speech_adh_with_recla_df['nom'])
# Compute recipe outputs from inputs
# TODO: Replace this part by your actual code that computes the output, as a Pandas dataframe
# NB: DSS also supports other kinds of APIs for reading and writing data. Please see doc.

#speech_recla_resilia_df = joa_speech_adh_with_recla_df # For this sample code, simply copy input to output


# Write recipe outputs
#speech_recla_resilia = dataiku.Dataset("speech_recla_resilia")
#speech_recla_resilia.write_with_schema(speech_recla_resilia_df)

# -------------------------------------------------------------------------------- NOTEBOOK-CELL: CODE
'''
liste_resi = []
for i in range(len(liste_texte)):
    dic_resi = {}
    texte = liste_texte[i]
    str_texte = str(texte)
    if 'résiliation' in str_texte:
        dic_resi['nom'] = liste_nom[i]
        dic_resi['texte'] = str_texte
    liste_resi.append(dic_resi)
'''

# -------------------------------------------------------------------------------- NOTEBOOK-CELL: CODE
#liste_mot_resi = ['résiliation' , 'résilié' , 'résilier' , 'résiliée']
liste_mot_resi = ['réclamation']
liste_resi = []
for texte in liste_texte:
    str_texte = str(texte)
    for mot in liste_mot_resi:
        if mot in str_texte:

            liste_resi.append(str_texte)

# -------------------------------------------------------------------------------- NOTEBOOK-CELL: CODE
print(len(liste_resi))

# -------------------------------------------------------------------------------- NOTEBOOK-CELL: CODE

liste_mot_resi = ['colère']
liste_r = []
for texte in liste_resi:
    str_texte = str(texte)
    for mot in liste_mot_resi:
        if mot in str_texte:

            liste_r.append(str_texte)
print(liste_r[1])

# -------------------------------------------------------------------------------- NOTEBOOK-CELL: CODE
speech_recla_resilia_df = pd.DataFrame(liste_resi)

# -------------------------------------------------------------------------------- NOTEBOOK-CELL: CODE
#speech_recla_resilia_df

# -------------------------------------------------------------------------------- NOTEBOOK-CELL: CODE
speech_recla_resilia = dataiku.Dataset("speech_recla_resilia")
speech_recla_resilia.write_with_schema(speech_recla_resilia_df)
