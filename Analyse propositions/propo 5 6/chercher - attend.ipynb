# %%
# -------------------------------------------------------------------------------- NOTEBOOK-CELL: CODE
# -*- coding: utf-8 -*-
import dataiku
import pandas as pd, numpy as np
from dataiku import pandasutils as pdu

# Read recipe inputs
speech_media_negatif = dataiku.Dataset("speech_media_negatif")
speech_media_negatif_df = speech_media_negatif.get_dataframe()

liste_texte = list(speech_media_negatif_df['text_diarise'])
liste_commentaire = list(speech_media_negatif_df['VERBATIM_SATISFACTION_GLOBALE_verbatim'])
liste_domaine = list(speech_media_negatif_df['domaine_acte'])
liste_famille = list(speech_media_negatif_df['famille_acte'])
liste_objet = list(speech_media_negatif_df['objet_acte'])
liste_nom = list(speech_media_negatif_df['nom'])
liste_rfap = list(speech_media_negatif_df['rfap'])
# Compute recipe outputs from inputs
# TODO: Replace this part by your actual code that computes the output, as a Pandas dataframe
# NB: DSS also supports other kinds of APIs for reading and writing data. Please see doc.

#speech_media_negatif_attente_df = speech_media_negatif_df # For this sample code, simply copy input to output


# Write recipe outputs
#speech_media_negatif_attente = dataiku.Dataset("speech_media_negatif_attente")
#speech_media_negatif_attente.write_with_schema(speech_media_negatif_attente_df)

# -------------------------------------------------------------------------------- NOTEBOOK-CELL: CODE
liste_all = []
for i in range(len(liste_commentaire)):
    texte = str(liste_commentaire[i])
    if 'attend' in texte:
        dic_texte = {}
        dic_texte['nom'] = liste_nom[i]
        dic_texte['commentaire'] = liste_commentaire[i]
        dic_texte['texte'] = liste_texte[i]
        dic_texte['domaine'] = liste_domaine[i]
        dic_texte['famille'] = liste_famille[i]
        dic_texte['objet'] = liste_objet[i]
        dic_texte['rfap'] = liste_rfap[i]
        liste_all.append(dic_texte)

# -------------------------------------------------------------------------------- NOTEBOOK-CELL: CODE
liste_all_2 = []
for i in range(len(liste_commentaire)):
    texte = str(liste_commentaire[i])
    if 'attente' in texte:
        dic_texte = {}
        dic_texte['nom'] = liste_nom[i]
        dic_texte['commentaire'] = liste_commentaire[i]
        dic_texte['texte'] = liste_texte[i]
        dic_texte['domaine'] = liste_domaine[i]
        dic_texte['famille'] = liste_famille[i]
        dic_texte['objet'] = liste_objet[i]
        dic_texte['rfap'] = liste_rfap[i]
        liste_all_2.append(dic_texte)
#print(len(liste_all_22))

# -------------------------------------------------------------------------------- NOTEBOOK-CELL: CODE
new_df_4 = pd.DataFrame(liste_all_2+liste_all)
speech_media_positif_attente = dataiku.Dataset("speech_media_negatif_attente")
speech_media_positif_attente.write_with_schema(new_df_4)
